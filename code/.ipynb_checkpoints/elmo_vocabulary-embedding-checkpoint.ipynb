# %% [markdown]
# ## Generate intial word embedding for headlines and description

# %%
import pickle
from collections import Counter
from itertools import chain
from keras.utils.data_utils import get_file
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - The embedding is limited to a fixed vocabulary size (`vocab_size`) but a vocabulary of all the words that appeared in the data is built.
#
# - Specify FN0 and FN_lines to correctly use the pickle file in pickles folder. This pickle file should have been generated by load_data.

# %%
FN = 'vocabulary-embedding'
FN0 = 'json_news' # this is the name of the data file which I assume you already have
FN_lines = 50000
embedtype = 'glove'

# %%
seed = 42
embedding_dim = 100
lower = True # whether to lowercase the text
n_sentences = 5
embed_fname = 'glove.6B.%dd.txt'%embedding_dim
fname = 'glove.6B.100d.5k.txt'
fname = 'elmo_10000_dim300.txt'
vocab_size = 24483 # vocab size in GloVe

# %% [markdown]
# # Methods

# %%
def get_vocab(lst):
    vocabcount = Counter(w for txt in lst for w in txt.split())
    vocab = list(map(lambda x: x[0], sorted(vocabcount.items(), key=lambda x: -x[1])))
    return vocab, vocabcount

# %%
def get_idx(vocab, vocabcount):
    word2idx = dict((word, idx+2) for idx,word in enumerate(vocab))
    word2idx['<empty>'] = 0
    word2idx['<eos>'] = 1    
    idx2word = dict((idx,word) for word,idx in word2idx.items())
    return word2idx, idx2word

# %% [markdown]
# # Read tokenized headlines and descriptions

# %%
with open('pickles/%s_%s.pickle'%(FN0, FN_lines), 'rb') as fp:
    df = pickle.load(fp) # keywords are not used in this project
    heads = df['title'].tolist()
    desc = df['content'].tolist()

if lower:
    heads = [' '.join(h[:n_sentences]).lower() for h in heads]
    desc = [' '.join(h[:n_sentences]).lower() for h in desc]

# %%
print(heads[0])
print(desc[0])
print(len(heads),len(desc))
# Out:
# worcester breakfast club for veteran give hunger it marching order
# veterans saluted worcester s first ever breakfast club for ex soldier which won over heart mind and belly the worcester breakfast club for hm forces veterans met at the postal order in foregate street at 10am on saturday the club is designed to allow veteran a place to meet socialise eat and drink giving hunger and loneliness their marching order father of two dave carney aged 43 of merrimans hill worcester set up the club after being inspired by other similar club across the country he said as you can see from the picture we had a good response
# 50000 50000

# %% [markdown]
# # Build vocabulary from given pickle file

# %%
vocab, vocabcount = get_vocab(heads+desc)

# %%
print('Most Popular Tokens:')
print(list(vocab)[:50])
print(len(list(vocab)))
vocab_size_d = len(list(vocab))
# Out:
# Most Popular Tokens:
# ['the', 'a', 'to', 'of', 'and', 'in', 's', 'for', 'on', 'is', 'with', 'it', 'that', 'at', 'by', 'from', 'wa', 'ha', 'this', 'be', 'are', 'will', '2015', 'an', 'new', 'have', 'year', 'said', 'i', 'his', 'he', 'you', 'their', 'more', 'but', 'we', 'one', 'or', '1', 'after', 'who', 'not', 'all', 'been', 'up', 'they', 'about', 'which', 'september', 'first']
# 141057

# %% [markdown]
# # Index words

# %%
word2idx, idx2word = get_idx(vocab, vocabcount)

# %% [markdown]
# # Word Embedding

# %% [markdown]
# ## Read GloVe

# %%
datadir = os.path.join('temp', 'datasets')
glove_name = os.path.join(datadir, embed_fname)
print(glove_name)
if not os.path.exists(glove_name):
    # If the specified text file does not exist, we assume that the glove.6B.zip file has not been downloaded
    path = 'glove.6B.zip'
    path = get_file(path, origin="http://nlp.stanford.edu/data/glove.6B.zip")   
    # Run unzip shell command to extract glove.6B.zip into ~/.keras/datasets
    # !unzip {path} -d {datadir}
glove_n_symbols = !wc -l {glove_name} # Line counts in glove_name (essentially the vocabulary size)
print(glove_n_symbols)
glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols
# Out:
# temp/datasets/glove.6B.100d.txt
# ['  400000 temp/datasets/glove.6B.100d.txt']
# 400000

# %%
# Keeps track of the index corresponding to each word in the vocabulary
glove_index_dict = {} 
glove_embedding_weights = np.empty((400000, embedding_dim)) # Saves vector representation for each word, ordered by its index
globale_scale = .1
with open(glove_name, 'r') as fp:
    i = 0
    for l in fp:
        # Each line in glove text file is the following format: { word vector-representation }
        l = l.strip().split() # strip and split each line separated by spaces
        w = l[0] # w is the first column in each line
        glove_index_dict[w] = i
        glove_embedding_weights[i,:] = list(map(float,l[1:]))
        i += 1
#glove_embedding_weights *= globale_scale 
# elmo_set = set()

# with open('/Users/elainelinlinlin/.keras/datasets/elmo_300.txt', 'r') as fp:
#     for l in fp:
#         l = l.strip().split()
#         w = l[0]
#         elmo_set.add(w)

# print(len(elmo_set))
# i = 0
# with open(glove_name, 'r') as fp:
#     with open('/Users/elainelinlinlin/.keras/datasets/glove.6B.100d.5k.txt', 'w') as output:
#         for line in fp:
#             l = line.strip().split()
#             w = l[0]
#             if w in elmo_set:
#                 output.write(line)
#                 i = i + 1

# print(i)

# %%
glove_embedding_weights.std()
# Out:
# 0.4081572760019029

# %%
for w,i in glove_index_dict.items():
    w = w.lower()
    if w not in glove_index_dict:
        glove_index_dict[w] = i

# %% [markdown]
# ## Embedding Matrix

# %% [markdown]
# Use GloVe to initialize embedding matrix

# %%
np.random.seed(seed)
shape = (vocab_size_d, embedding_dim)
scale = glove_embedding_weights.std()*np.sqrt(12)/2 # uniform and not normal
embedding = np.random.uniform(low=-scale, high=scale, size=shape)
#print('random-embedding/glove scale', scale, 'std', embedding.std())
# Copy from glove weights of words that appear in our short vocabulary (idx2word)
c = 0
for i in range(min(vocab_size_d, len(idx2word))):
    w = idx2word[i] # Word at the i-th index in idx2word
    g = glove_index_dict.get(w, glove_index_dict.get(w.lower())) # The corresponding index of w in glove_index_dict
    if g is not None:
        # Populate the weights for the corresponding words into embedding if the word occurs in glove
        embedding[i,:] = glove_embedding_weights[g,:]
        c += 1
print('number of tokens, in small vocab, found in glove and copied to embedding', c,c/float(vocab_size))
# Out:
# number of tokens, in small vocab, found in glove and copied to embedding 91113 3.7214802107584855

# %% [markdown]
# #### Lots of words in the full vocabulary (word2idx) are not found in GloVe vocabulary:
# Build an alterantive which will map them to their closest match in glove but only if the match
# is good enough (cos distance above `glove_thr`)

# %%
glove_thr = 0.5

# %%
word2glove = {}
for w in word2idx:
    if w in glove_index_dict:
        g = w
    elif w.lower() in glove_index_dict:
        g = w.lower()
    elif w.startswith('#') and w[1:] in glove_index_dict:
        g = w[1:]
    elif w.startswith('#') and w[1:].lower() in glove_index_dict:
        g = w[1:].lower()
    else:
        continue
    word2glove[w] = g

# %% [markdown]
# For every word outside the embedding matrix find the closest word inside the mebedding matrix.
# Use cos distance of GloVe vectors.
#
# Allow for the last `nb_unknown_words` words inside the embedding matrix to be considered to be outside.
# Dont accept distances below `glove_thr`

# %%
normed_embedding = embedding/np.array([np.sqrt(np.dot(gweight,gweight)) for gweight in embedding])[:,None]

nb_unknown_words = 100

glove_match = []
for w,idx in word2idx.items():
    if idx >= vocab_size-nb_unknown_words and w.isalpha() and w in word2glove:
        gidx = glove_index_dict[word2glove[w]]
        gweight = glove_embedding_weights[gidx,:].copy()
        # find row in embedding that has the highest cos score with gweight
        gweight /= np.sqrt(np.dot(gweight,gweight))
        score = np.dot(normed_embedding[:vocab_size-nb_unknown_words], gweight)
        while True:
            embedding_idx = score.argmax()
            s = score[embedding_idx]
            if s < glove_thr:
                break
            if idx2word[embedding_idx] in word2glove :
                glove_match.append((w, embedding_idx, s)) 
                break
            score[embedding_idx] = -1
glove_match.sort(key = lambda x: -x[2])
print('# of glove substitutes found', len(glove_match))
# Out:
# # of glove substitutes found 47346

# %% [markdown]
# manually check that the worst substitutions we are going to do are good enough

# %%
for orig, sub, score in glove_match[:10]:
    print(score, orig,'=>', idx2word[sub])
# Out:
# 0.9885466095046858 itar => tass
# 0.9772074449272279 demonstrators => protesters
# 0.9767594360838658 recep => tayyip
# 0.9707368506999493 amro => abn
# 0.9655081784167914 interfax => tass
# 0.9651710380165542 tonnes => tons
# 0.960148139581595 lingus => aer
# 0.9584697672522862 downstairs => upstairs
# 0.9542632787210998 gerais => minas
# 0.9521244376354177 goaltender => goalie

# %% [markdown]
# Build a lookup table of index of outside words to index of inside words

# %%
glove_idx2idx = dict((word2idx[w],embedding_idx) for  w, embedding_idx, _ in glove_match)

# %% [markdown]
# # Data

# %%
# Each row in Y is an array that represents a headline word by word, denoted by its index mapped by word2idx.
# e.g. 
#  heads[0].split() == ['New', 'York', 'Time']
#  Y[0] == [1065, 1424, 5309]
#  word2idx['New'] == 1065
# len(Y) should match len(heads)
Y = [[word2idx[token] for token in headline.split()] for headline in heads]
len(Y)
# Out:
# 50000

# %%
plt.hist(list(map(len,Y)),bins=50)
plt.title('Length of headlines distribution')
plt.xlabel('Length of headlines')
plt.ylabel('Total occurrences')
# Out:
# Text(0,0.5,'Total occurrences')

# %%
# Each row in X is an array that represents a description word by word, denoted by its index mapped by word2idx.
# e.g. 
#  desc[0].split() == ['New', 'York', 'Time']
#  X[0] == [1065, 1424, 5309]
#  word2idx['New'] == 1065
# len(X) should match len(desc)
X = [[word2idx[token] for token in d.split()] for d in desc]
len(X)
# Out:
# 50000

# %%
plt.hist(list(map(len,X)),bins=50);
plt.title('Length of description distribution')
plt.xlabel('Length of descriptions')
plt.ylabel('Total occurrences')
# Out:
# Text(0,0.5,'Total occurrences')

# %%
with open('pickles/%s-%s-%s-vocab-embedding.pickle'%(FN0, FN_lines,embedtype),'wb') as fp:
    pickle.dump((embedding, idx2word, word2idx, glove_idx2idx),fp,-1)

# %%
with open('pickles/%s-%s-%s-vocab-embedding.data.pickle'%(FN0, FN_lines,embedtype),'wb') as fp:
    pickle.dump((X,Y),fp,-1)

# %%
print('Vocabulary embedding completed!')
# Out:
# Vocabulary embedding completed!
